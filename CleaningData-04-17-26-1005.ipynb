# %%
import mod as m 
import numpy as np 
import matplotlib.pyplot as plt 
ind = True

# %% [markdown]
# ## Read in data

# %%
## USER INPUT

date = '04-17-26' 
filename = "1005Pa.txt"

arr = np.loadtxt(f"Data/HighPressureTesting-{date}/"+filename, usecols=range(1, 8))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 6
#       2
#       3 date = '04-17-26'
#       4 filename = "1005Pa.txt"
#       5
# ----> 6 arr = np.loadtxt(f"Data/HighPressureTesting-{date}/"+filename, usecols=range(1, 8))
#
# File c:\Users\ual-laptop\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_npyio_impl.py:1384, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1381 if isinstance(delimiter, bytes):
#    1382     delimiter = delimiter.decode('latin1')
# -> 1384 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1385             converters=converters, skiplines=skiprows, usecols=usecols,
#    1386             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1387             max_rows=max_rows, quote=quotechar)
#    1389 return arr
#
# File c:\Users\ual-laptop\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_npyio_impl.py:1011, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1009     fname = os.fspath(fname)
#    1010 if isinstance(fname, str):
# -> 1011     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1012     if encoding is None:
#    1013         encoding = getattr(fh, 'encoding', 'latin1')
#
# File c:\Users\ual-laptop\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File c:\Users\ual-laptop\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: Data/HighPressureTesting-04-17-26/1005Pa.txt not found.

# %%
x = arr[:,0]
y = arr[:,1]
z = arr[:,2]

# %%
m.vis(x,y,z,date)

# %% [markdown]
# ## Reference bars

# %%
xb = x[4:16]
yb = y[4:16]
zb = z[4:16]

m.vis(xb, yb, zb, date)

# %% [markdown]
# ## Crop

# %%
# USER INPUT 
mask = (x > -2000) & (y > -600) & (z > -580) & (z < 780)


x,y,z = x[mask], y[mask], z[mask]
m.vis(x,y,z,date)

# %% [markdown]
# ## Rotate based on Reference bars

# %%
ref = np.vstack([xb, yb, zb]).T  
pts = np.vstack([x, y, z]).T 
Xr, Yr, Zr, X, Y, Z, _, _ = m.svd_rotate(ref, pts)

# %%
m.vis(X,Y,Z, date, ind=True)

# %% [markdown]
# ## Rotate, ref -points

# %%
pts = np.vstack([x, y, z]).T 
Xr, Yr, Zr, X, Y, Z, _, _ = m.svd_rotate(pts, pts)
m.vis(X,Y,Z, date)

# %% [markdown]
# ## make mask

# %%
x0, y0 = -50, 20

r = np.sqrt( (X-x0)**2 + (Y-y0)**2 ) 

rlim = 500
r_ring = 551

mask = r < rlim
mask_ring = r < r_ring

xx, yy, zz          = X[mask], Y[mask], Z[mask]
xx_r, yy_r, zz_r    = X[mask_ring], Y[mask_ring], Z[mask_ring]

# %%
theta = np.linspace(0,360,100)
x_c, y_c = rlim * np.cos(np.deg2rad(theta)) + x0,   rlim * np.sin(np.deg2rad(theta)) + y0
x_r, y_r = r_ring * np.cos(np.deg2rad(theta)) + x0, r_ring * np.sin(np.deg2rad(theta)) + y0

# %%
fig = plt.figure(figsize=(10, 10))

ax2 = fig.add_subplot(222)
ax2.scatter(X,       Y, c='green')
ax2.scatter(xx_r, yy_r, c='red')
ax2.scatter(xx,     yy, c='blue')

ax2.plot(x_c, y_c, c = 'blue')
ax2.plot(x_r, y_r, c='green')

ax2.set_aspect("equal")
ax2.grid()

# %%
fig = plt.figure(figsize=(12, 10))

# 3D plot
ax1 = fig.add_subplot(221, projection='3d')
ax1.scatter(xx, yy, zz, c='blue')
# ax1.set_title('3D Plot')

# XY plane
ax2 = fig.add_subplot(222)
ax2.scatter(xx, yy, c='red')
ax2.plot(x_c, y_c)
if ind:
    for i, (xi, yi) in enumerate(zip(xx, yy)):
        ax2.text(xi, yi, str(i), fontsize=9, color='black')

ax2.set_aspect("equal")
ax2.grid()

# XZ plane
ax3 = fig.add_subplot(223)
ax3.scatter(xx, zz)
ax3.grid()

# YZ plane
ax4 = fig.add_subplot(224)
ax4.scatter(yy, zz, c='purple')
ax4.grid()

# %% [markdown]
# ## Adjust coord with points

# %%
pts = np.vstack([xx, yy, zz]).T  
refs = np.vstack([xx_r, yy_r, zz_r]).T
Xr, Yr, Zr, X, Y, Z, _, _ = m.svd_rotate(pts, pts)

# %%
m.vis(X,Y,Z, date, ind=True)
len(Xr)
# Out:
# 93

# %%
plt.scatter(X, Y)
for i, (xi, yi) in enumerate(zip(X, Y)):
    plt.text(xi, yi, str(i), fontsize=9, color='black')

# %%
xx_r, yy_r, zz_r = np.delete(xx_r, [122, 126, 129]), np.delete(yy_r, [122, 126, 129]), np.delete(zz_r, [122, 126, 129])

# %%
# write_txt_from_arrays(filename, np.append(xx, xr), np.append(yy, yr) , np.append(zz, zr))
m.write_txt_from_arrays("WithRing-"+filename, xx_r, -1*yy_r, -1*zz_r, date)
